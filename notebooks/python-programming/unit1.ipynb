# %% [markdown]
# # Unit 1 · Your First Conversation with a Computer
#
# **Learn with Adi — Python Programming (Beginner · Foundations)**
#
# This notebook mirrors the practice from Unit 1. Here in Colab, `input()` *really* pauses and waits for your keyboard — the honest version of what the in-page runner simulates. Run a cell with **Shift+Enter**.
#
# Study notes: https://aditya-402.github.io/learn-with-adi/series/python-programming/unit1.html

# %% [markdown]
# ## 1.1 · Meet the machine — your first program

# %%
print("Hello, world")

# %%
# P2 — instructions run in order. Add a third line printing "Third".
print("First")
print("Second")

# %% [markdown]
# ## 1.2 · print(), properly — quoted is repeated, unquoted is understood

# %%
print("2 + 3")           # quoted: repeated exactly
print(2 + 3)             # unquoted: understood, computed
print("Result:", 2 + 3)  # the comma joins both worlds with a space

# %%
# P2 — one print line, commas, and the number 3 unquoted:
# target ->  I have 3 dosas
print("...")

# %% [markdown]
# ## 1.3 · Errors are messages — run these, read the LAST line of each report, then fix

# %%
prnt("Good morning")   # run as-is first; read the report; then fix

# %%
print("Bye for now)    # a different kind of stuck — compare the report

# %% [markdown]
# ## 1.4 · The program listens — input() (here it genuinely waits for you)

# %%
name = input("What is your name? ")
print("Hello,", name, "— welcome aboard!")

# %%
# Your build — the greeter that answers back.
# At least three questions, a reply after each, and a sign-off line.
name = input("What is your name? ")
print("Hello,", name)

# %% [markdown]
# ## Problem bank
#
# 1. **The banner** — print a three-line banner with `=` borders around ` LEARN PYTHON`.
# 2. **Three bugs** — fix one bug per line: `print("Monday)` · `prin("Tuesday")` · `print(Wednesday)`.
# 3. **The compliment machine** — ask `How old are you? `, store in `age`, reply `Wow, <age> is a great age!` using commas.
# 4. **The mini interview** — three questions, one summary line built from all three answers.

# %%
# your problem-bank workspace
